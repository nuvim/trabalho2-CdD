# %%
import pandas as pd

# link direto para o dataset que contem os dados da covid19
url = 'https://data.brasil.io/dataset/covid19/caso_full.csv.gz'
print("Download e carregamento dos dados da URL")

# descompactação do arquivo
df_covid = pd.read_csv(url, compression='gzip', low_memory=False)

print("\nDados carregados")
print("\nExibindo 5 dados aleatórios do Dataset")
display(df_covid.sample(5, random_state=42))
# Out:
# Download e carregamento dos dados da URL
#
# Dados carregados
#
# Exibindo 5 dados aleatórios do Dataset
#                          city  city_ibge_code        date  \
# 3610819  Presidente Bernardes       3541208.0  2021-08-12
# 2060265         Queimada Nova       2208650.0  2020-05-26
# 1149639                Divino       3122009.0  2021-01-22
# 3138152           Barra Velha       4202107.0  2021-02-24
# 2298430         Salgado Filho       4122800.0  2020-12-25
#
#          epidemiological_week  estimated_population  \
# 3610819                202132               13023.0
# 2060265                202022                9017.0
# 1149639                202103               19976.0
# 3138152                202108               29860.0
# 2298430                202052                3483.0
#
#          estimated_population_2019  is_last  is_repeated  \
# 3610819                    13106.0    False        False
# 2060265                     8992.0    False        False
# 1149639                    19931.0    False        False
# 3138152                    29168.0    False        False
# 2298430                     3580.0    False        False
#
#          last_available_confirmed  \
# 3610819                      1299
# 2060265                         9
# 1149639                       272
# 3138152                      2475
# 2298430                        87
#
#          last_available_confirmed_per_100k_inhabitants last_available_date  \
# 3610819                                     9974.66022          2021-08-12
# 2060265                                       99.81147          2020-05-26
# 1149639                                     1361.63396          2021-01-22
# 3138152                                     8288.68051          2021-02-24
# 2298430                                     2497.84668          2020-12-25
#
#          last_available_death_rate  last_available_deaths  order_for_place  \
# 3610819                     0.0308                     40              461
# 2060265                     0.0000                      0               29
# 1149639                     0.0368                     10              262
# 3138152                     0.0186                     46              322
# 2298430                     0.0000                      0              210
#
#         place_type state  new_confirmed  new_deaths
# 3610819       city    SP              1           1
# 2060265       city    PI              2           0
# 1149639       city    MG              4           1
# 3138152       city    SC              1           1
# 2298430       city    PR              0           0

# %%
print("Informações Gerais e Tipos de Dados")
df_covid.info(verbose=True, show_counts=True)

print("\n\nContagem de Valores Nulos por Coluna")
print(df_covid.isnull().sum())

print("\n\nNomes de todas as colunas (um por linha)")
for coluna in df_covid.columns:
  print(coluna)
# Out:
# Informações Gerais e Tipos de Dados
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3853648 entries, 0 to 3853647
# Data columns (total 18 columns):
#  #   Column                                         Non-Null Count    Dtype
# ---  ------                                         --------------    -----
#  0   city                                           3833529 non-null  object
#  1   city_ibge_code                                 3840002 non-null  float64
#  2   date                                           3853648 non-null  object
#  3   epidemiological_week                           3853648 non-null  int64
#  4   estimated_population                           3840002 non-null  float64
#  5   estimated_population_2019                      3840002 non-null  float64
#  6   is_last                                        3853648 non-null  bool
#  7   is_repeated                                    3853648 non-null  bool
#  8   last_available_confirmed                       3853648 non-null  int64
#  9   last_available_confirmed_per_100k_inhabitants  3824482 non-null  float64
#  10  last_available_date                            3853648 non-null  object
#  11  last_available_death_rate                      3853648 non-null  float64
#  12  last_available_deaths                          3853648 non-null  int64
#  13  order_for_place                                3853648 non-null  int64
#  14  place_type                                     3853648 non-null  object
#  15  state                                          3853648 non-null  object
#  16  new_confirmed                                  3853648 non-null  int64
#  17  new_deaths                                     3853648 non-null  int64
# dtypes: bool(2), float64(5), int64(6), object(5)
# memory usage: 477.8+ MB
#
#
# Contagem de Valores Nulos por Coluna
# city                                             20119
# city_ibge_code                                   13646
# date                                                 0
# epidemiological_week                                 0
# estimated_population                             13646
# estimated_population_2019                        13646
# is_last                                              0
# is_repeated                                          0
# last_available_confirmed                             0
# last_available_confirmed_per_100k_inhabitants    29166
# last_available_date                                  0
# last_available_death_rate                            0
# last_available_deaths                                0
# order_for_place                                      0
# place_type                                           0
# state                                                0
# new_confirmed                                        0
# new_deaths                                           0
# dtype: int64
#
#
# Nomes de todas as colunas (um por linha)
# city
# city_ibge_code
# date
# epidemiological_week
# estimated_population
# estimated_population_2019
# is_last
# is_repeated
# last_available_confirmed
# last_available_confirmed_per_100k_inhabitants
# last_available_date
# last_available_death_rate
# last_available_deaths
# order_for_place
# place_type
# state
# new_confirmed
# new_deaths
